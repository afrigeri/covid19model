# %%
import requests
import pandas as pd
import seaborn as sns
import io
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# %%
DATA="https://covid.ourworldindata.org/data/full_data.csv"

# %%
s=requests.get(DATA).content
ww_data=pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
# Subsetting WW data to China and Italy
# (ww_data.location=='China')
cn_it_data = ww_data[ (ww_data.location=='China') | (ww_data.location=='Italy') | (ww_data.location=='Spain') | (ww_data.location=='United States') | (ww_data.location=='France')  ]
#ch_it_data["total"] = ch_it_data.Series1 + ch_it_data.Series2

# %%
plt.figure(figsize=(16,10))
chart = sns.lineplot(data=cn_it_data, x='date', y='total_cases', hue='location')
plt.xticks(rotation=65, horizontalalignment='right')
ax = plt.axes()        
ax.xaxis.grid() # vertical lines

# %%
ax = sns.barplot(x="date", y="total_cases", hue='location', data=cn_it_data)
#stacked=True
plt.xticks(rotation=65, horizontalalignment='right')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-82-defbaa16817b> in <module>
# ----> 1 ax = sns.barplot(x=cn_it_data.Group, y="total_cases", hue='location', data=cn_it_data)
#       2 #stacked=True
#       3 plt.xticks(rotation=65, horizontalalignment='right')
#
# ~/Library/Python/3.6/lib/python/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Group'

# %%
 ww_data[(ww_data.location=='China')].plot(kind='bar', stacked=True);

# %%
 ww_data[(ww_data.location=='Italy')].plot(kind='bar', stacked=True);
